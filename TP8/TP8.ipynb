# %%
import numpy as np
from sklearn.neural_network import MLPClassifier

x_train=np.array([[0,0],[0,1]])
y_train=np.array([0,1])


x_test=np.array([[2.,2.],[-1.,-2.]])


MLP_clf = MLPClassifier(hidden_layer_sizes=(4), activation='logistic', solver='lbfgs', alpha=0.0001, learning_rate='adaptive')
MLP_clf.fit(x_train, y_train)
y_pred = MLP_clf.predict(x_test)
print(y_pred)

print ("les coefficients sont: "+str( MLP_clf.coefs_))
print ("les biais des couche cachees  et la sortie sont :" +str(MLP_clf.intercepts_))
# Out:
# [1 0]
# les coefficients sont: [array([[ 1.43489068e-02,  5.07534374e-02, -9.34337985e-02,
#         -2.59903078e-03],
#        [-4.64025661e+00, -4.62478434e+00,  1.02293911e+00,
#         -3.73727076e+00]]), array([[-6.35781503],
#        [-6.29120183],
#        [ 1.43169671],
#        [-5.15952764]])]
# les biais des couche cachees  et la sortie sont :[array([2.39485147, 2.35046331, 0.27027977, 1.86539351]), array([7.98475113])]

# %%
import numpy as np
from sklearn.neural_network import MLPClassifier

x_train=np.array([[0,0],[1,1]])
y_train=np.array([[0, 1],[1, 1]])
x_test=np.array([[2.,2.],[-1.,-2.]])
MLP_clf = MLPClassifier(hidden_layer_sizes=(4), activation='logistic', solver='lbfgs', alpha=0.0001, learning_rate='adaptive')
MLP_clf.fit(x_train, y_train)
y_pred = MLP_clf.predict(x_test)
print("les prediction sont :" +str(y_pred))
print ("les coefficients sont: "+str( MLP_clf.coefs_))
print ("les biais des couche cachees  et la sortie sont :" +str(MLP_clf.intercepts_))
# Out:
# les prediction sont :[[1 1]
#  [0 1]]
# les coefficients sont: [array([[ 1.404451  , -2.77703753,  2.4980617 , -2.73815629],
#        [ 1.41587339, -2.77495584,  2.49761427, -2.73895053]]), array([[ 2.53183829,  0.15595431],
#        [-5.99050145,  0.18102598],
#        [ 3.53072429,  0.18911753],
#        [-6.05546327,  0.11455512]])]
# les biais des couche cachees  et la sortie sont :[array([-1.3454215 ,  3.04150961, -3.23784567,  2.99942232]), array([ 3.30372972, 10.16717894])]

# %%
from sklearn.model_selection import GridSearchCV

X_train2 = np.array([[0,0],[1,1]])
y_train2 = np.array([[0,1],[1,1]])
X_test2 = np.array([[2.,2.],[-1.,-2.]])
param_grid = {
    'hidden_layer_sizes': [2, 3, 4, 5, 6, 7, 8],

    }
 
mlp_clf = GridSearchCV(MLPClassifier(activation = 'logistic', solver = 'lbfgs', learning_rate = 'adaptive', max_iter = 100), param_grid, cv=2, n_jobs=4, verbose=1)
mlp_clf.fit(X_train2, y_train2)
y_predict = mlp_clf.predict(X_test2)
print("Les classes prédites pour les données de test {} sont: {} respectivement.".format(X_test, y_predict))
print("La meilleure configuration est: ", mlp_clf.best_params_)
# Out:
# Fitting 2 folds for each of 7 candidates, totalling 14 fits
# Les classes prédites pour les données de test [[5.8 2.8 5.1 2.4]
#  [6.  2.2 4.  1. ]
#  [5.5 4.2 1.4 0.2]
#  [7.3 2.9 6.3 1.8]
#  [5.  3.4 1.5 0.2]
#  [6.3 3.3 6.  2.5]
#  [5.  3.5 1.3 0.3]
#  [6.7 3.1 4.7 1.5]
#  [6.8 2.8 4.8 1.4]
#  [6.1 2.8 4.  1.3]
#  [6.1 2.6 5.6 1.4]
#  [6.4 3.2 4.5 1.5]
#  [6.1 2.8 4.7 1.2]
#  [6.5 2.8 4.6 1.5]
#  [6.1 2.9 4.7 1.4]
#  [4.9 3.6 1.4 0.1]
#  [6.  2.9 4.5 1.5]
#  [5.5 2.6 4.4 1.2]
#  [4.8 3.  1.4 0.3]
#  [5.4 3.9 1.3 0.4]
#  [5.6 2.8 4.9 2. ]
#  [5.6 3.  4.5 1.5]
#  [4.8 3.4 1.9 0.2]
#  [4.4 2.9 1.4 0.2]
#  [6.2 2.8 4.8 1.8]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.8 1.9 0.4]
#  [6.2 2.9 4.3 1.3]
#  [5.  2.3 3.3 1. ]
#  [5.  3.4 1.6 0.4]
#  [6.4 3.1 5.5 1.8]
#  [5.4 3.  4.5 1.5]
#  [5.2 3.5 1.5 0.2]
#  [6.1 3.  4.9 1.8]
#  [6.4 2.8 5.6 2.2]
#  [5.2 2.7 3.9 1.4]
#  [5.7 3.8 1.7 0.3]
#  [6.  2.7 5.1 1.6]
#  [5.9 3.  4.2 1.5]
#  [5.8 2.6 4.  1.2]
#  [6.8 3.  5.5 2.1]
#  [4.7 3.2 1.3 0.2]
#  [6.9 3.1 5.1 2.3]
#  [5.  3.5 1.6 0.6]
#  [5.4 3.7 1.5 0.2]
#  [5.  2.  3.5 1. ]
#  [6.5 3.  5.5 1.8]
#  [6.7 3.3 5.7 2.5]
#  [6.  2.2 5.  1.5]
#  [6.7 2.5 5.8 1.8]
#  [5.6 2.5 3.9 1.1]
#  [7.7 3.  6.1 2.3]
#  [6.3 3.3 4.7 1.6]
#  [5.5 2.4 3.8 1.1]
#  [6.3 2.7 4.9 1.8]
#  [6.3 2.8 5.1 1.5]
#  [4.9 2.5 4.5 1.7]
#  [6.3 2.5 5.  1.9]
#  [7.  3.2 4.7 1.4]
#  [6.5 3.  5.2 2. ]
#  [6.  3.4 4.5 1.6]
#  [4.8 3.1 1.6 0.2]
#  [5.8 2.7 5.1 1.9]
#  [5.6 2.7 4.2 1.3]
#  [5.6 2.9 3.6 1.3]
#  [5.5 2.5 4.  1.3]
#  [6.1 3.  4.6 1.4]
#  [7.2 3.2 6.  1.8]
#  [5.3 3.7 1.5 0.2]
#  [4.3 3.  1.1 0.1]
#  [6.4 2.7 5.3 1.9]
#  [5.7 3.  4.2 1.2]
#  [5.4 3.4 1.7 0.2]
#  [5.7 4.4 1.5 0.4]
#  [6.9 3.1 4.9 1.5]
#  [4.6 3.1 1.5 0.2]
#  [5.9 3.  5.1 1.8]
#  [5.1 2.5 3.  1.1]
#  [4.6 3.4 1.4 0.3]
#  [6.2 2.2 4.5 1.5]
#  [7.2 3.6 6.1 2.5]
#  [5.7 2.9 4.2 1.3]
#  [4.8 3.  1.4 0.1]
#  [7.1 3.  5.9 2.1]
#  [6.9 3.2 5.7 2.3]
#  [6.5 3.  5.8 2.2]
#  [6.4 2.8 5.6 2.1]
#  [5.1 3.8 1.6 0.2]
#  [4.8 3.4 1.6 0.2]
#  [6.5 3.2 5.1 2. ]
#  [6.7 3.3 5.7 2.1]
#  [4.5 2.3 1.3 0.3]
#  [6.2 3.4 5.4 2.3]
#  [4.9 3.  1.4 0.2]
#  [5.7 2.5 5.  2. ]
#  [6.9 3.1 5.4 2.1]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.6 1.4 0.2]
#  [7.2 3.  5.8 1.6]
#  [5.1 3.5 1.4 0.3]
#  [4.4 3.  1.3 0.2]
#  [5.4 3.9 1.7 0.4]
#  [5.5 2.3 4.  1.3]
#  [6.8 3.2 5.9 2.3]
#  [7.6 3.  6.6 2.1]] sont: [[1 1]
#  [0 1]] respectivement.
# La meilleure configuration est:  {'hidden_layer_sizes': 2}
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  14 out of  14 | elapsed:    0.0s finished

# %%
import numpy as np
import time
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Perceptron 
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

iris = datasets.load_iris()

X= iris.data
y= iris.target
start_time = time.time()



def Hiddenlayersizes3(x1,y1,z1):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7,random_state=0)
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    MLP_clf = MLPClassifier(hidden_layer_sizes=(x1,y1,z1), activation='logistic', solver='lbfgs', learning_rate='adaptive')
    MLP_clf.fit(X_train, y_train)
    y_pred = MLP_clf.predict(X_test)
    score = MLP_clf.score(X_test, y_test)
    end_time = time.time()
    print("pour les 3 couche de taille : " +str(x1)+"-->"+str(y1)+"-->"+str(z1))
    print('temps ecoule = '+str(end_time - start_time))
    return print("le score est :"+str(score)) 
def Hiddenlayersizes2(x1,y1):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7,random_state=0)
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    MLP_clf = MLPClassifier(hidden_layer_sizes=(x1,y1), activation='logistic', solver='lbfgs', learning_rate='adaptive')
    MLP_clf.fit(X_train, y_train)
    y_pred = MLP_clf.predict(X_test)
    score = MLP_clf.score(X_test, y_test)
    end_time = time.time()
    print("pour les 2 couche de taille : " +str(x1)+"-->"+str(y1))
    print('temps ecoule = '+str(end_time - start_time))
    return print("le score est :"+str(score)) 
def Hiddenlayersizes4(x1,y1,z1,c1):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7,random_state=0)
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    MLP_clf = MLPClassifier(hidden_layer_sizes=(x1,y1,z1,c1), activation='logistic', solver='lbfgs', learning_rate='adaptive')
    MLP_clf.fit(X_train, y_train)
    y_pred = MLP_clf.predict(X_test)
    score = MLP_clf.score(X_test, y_test)
    end_time = time.time()
    print("pour les 4 couche de taille : " +str(x1)+"-->"+str(y1)+"-->"+str(z1)+"-->"+str(c1))
    print('temps ecoule = '+str(end_time - start_time))
    print(MLP_clf.n_iter_)
    return print("le score est :"+str(score)) 
# pour differentes taille des 2 couche de neuron 
Hiddenlayersizes2(1,15)
Hiddenlayersizes2(10,100)
Hiddenlayersizes2(200,300)

# pour differentes taille des 3 couche de neuron 
Hiddenlayersizes3(1,15,30)
Hiddenlayersizes3(10,100,200)
Hiddenlayersizes3(100,150,300)

# pour differentes taille des 4 couche de neuron 
Hiddenlayersizes4(1,15,30,90)
Hiddenlayersizes4(10,100,200,300)
# Out:
# C:\Users\utilisateur\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:471: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# pour les 2 couche de taille : 1-->15
# temps ecoule = 0.12578940391540527
# le score est :0.9619047619047619
# pour les 2 couche de taille : 10-->100
# temps ecoule = 0.20779061317443848
# le score est :0.9523809523809523
# pour les 2 couche de taille : 200-->300
# temps ecoule = 1.0955638885498047
# le score est :0.9619047619047619
# pour les 3 couche de taille : 1-->15-->30
# temps ecoule = 1.3302545547485352
# le score est :0.9619047619047619
# pour les 3 couche de taille : 10-->100-->200
# temps ecoule = 1.8461182117462158
# le score est :0.9523809523809523
# pour les 3 couche de taille : 100-->150-->300
# temps ecoule = 2.8674685955047607
# le score est :0.9619047619047619
# C:\Users\utilisateur\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:471: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# pour les 4 couche de taille : 1-->15-->30-->90
# temps ecoule = 3.2577831745147705
# 200
# le score est :0.9619047619047619
# pour les 4 couche de taille : 10-->100-->200-->300
# temps ecoule = 4.508488655090332
# 65
# le score est :0.9619047619047619

# %%
from sklearn import svm
clsvm = svm.SVC(kernel='poly')
clsvm.fit(X_train, y_train)
y_pred = clsvm.predict(X_test)
score = clsvm.score(X_test, y_test)
print ("le score avec un classifieur a noyau de type SVM ="+str(score))
# Out:
# le score avec un classifieur a noyau de type SVM =0.9428571428571428

# %%
from statistics import mean, stdev
for i in range(len(X)):
    print("la valeur moyenne de l'attribut {} est: {}".format(i+1,mean(X[i])))
    print("l'écart-type de l'attribut {} est: {}".format(i+1,stdev(X[i])))
# Out:
# la valeur moyenne de l'attribut 1 est: 2.55
# l'écart-type de l'attribut 1 est: 2.1794494717703365
# la valeur moyenne de l'attribut 2 est: 2.375
# l'écart-type de l'attribut 2 est: 2.036950334855189
# la valeur moyenne de l'attribut 3 est: 2.35
# l'écart-type de l'attribut 3 est: 1.997498435543818
# la valeur moyenne de l'attribut 4 est: 2.35
# l'écart-type de l'attribut 4 est: 1.9122412679017953
# la valeur moyenne de l'attribut 5 est: 2.55
# l'écart-type de l'attribut 5 est: 2.1563858652847823
# la valeur moyenne de l'attribut 6 est: 2.85
# l'écart-type de l'attribut 6 est: 2.230844384233617
# la valeur moyenne de l'attribut 7 est: 2.425
# l'écart-type de l'attribut 7 est: 1.9362764954072718
# la valeur moyenne de l'attribut 8 est: 2.525
# l'écart-type de l'attribut 8 est: 2.109304782781916
# la valeur moyenne de l'attribut 9 est: 2.225
# l'écart-type de l'attribut 9 est: 1.8227726133558184
# la valeur moyenne de l'attribut 10 est: 2.4
# l'écart-type de l'attribut 10 est: 2.06881608655772
# la valeur moyenne de l'attribut 11 est: 2.7
# l'écart-type de l'attribut 11 est: 2.3079572497485015
# la valeur moyenne de l'attribut 12 est: 2.5
# l'écart-type de l'attribut 12 est: 2.016597794967223
# la valeur moyenne de l'attribut 13 est: 2.3249999999999997
# l'écart-type de l'attribut 13 est: 2.0320351046836436
# la valeur moyenne de l'attribut 14 est: 2.125
# l'écart-type de l'attribut 14 est: 1.8839232114570557
# la valeur moyenne de l'attribut 15 est: 2.8
# l'écart-type de l'attribut 15 est: 2.5664502073226876
# la valeur moyenne de l'attribut 16 est: 3.0
# l'écart-type de l'attribut 16 est: 2.467117075995111
# la valeur moyenne de l'attribut 17 est: 2.75
# l'écart-type de l'attribut 17 est: 2.307234997422962
# la valeur moyenne de l'attribut 18 est: 2.5749999999999997
# l'écart-type de l'attribut 18 est: 2.1437894797142123
# la valeur moyenne de l'attribut 19 est: 2.875
# l'écart-type de l'attribut 19 est: 2.3697749541535233
# la valeur moyenne de l'attribut 20 est: 2.675
# l'écart-type de l'attribut 20 est: 2.173131381210073
# la valeur moyenne de l'attribut 21 est: 2.6750000000000003
# l'écart-type de l'attribut 21 est: 2.2381167678802343
# la valeur moyenne de l'attribut 22 est: 2.675
# l'écart-type de l'attribut 22 est: 2.1203380233664
# la valeur moyenne de l'attribut 23 est: 2.35
# l'écart-type de l'attribut 23 est: 2.087262960593769
# la valeur moyenne de l'attribut 24 est: 2.65
# l'écart-type de l'attribut 24 est: 1.9958289839896937
# la valeur moyenne de l'attribut 25 est: 2.5749999999999997
# l'écart-type de l'attribut 25 est: 1.9771612647092462
# la valeur moyenne de l'attribut 26 est: 2.45
# l'écart-type de l'attribut 26 est: 2.048576741707927
# la valeur moyenne de l'attribut 27 est: 2.6
# l'écart-type de l'attribut 27 est: 2.0199009876724157
# la valeur moyenne de l'attribut 28 est: 2.6
# l'écart-type de l'attribut 28 est: 2.2015146301277824
# la valeur moyenne de l'attribut 29 est: 2.55
# l'écart-type de l'attribut 29 est: 2.2052966542697456
# la valeur moyenne de l'attribut 30 est: 2.4250000000000003
# l'écart-type de l'attribut 30 est: 1.95
# la valeur moyenne de l'attribut 31 est: 2.425
# l'écart-type de l'attribut 31 est: 1.9771612647092462
# la valeur moyenne de l'attribut 32 est: 2.6750000000000003
# l'écart-type de l'attribut 32 est: 2.199052826408073
# la valeur moyenne de l'attribut 33 est: 2.725
# l'écart-type de l'attribut 33 est: 2.3386249521175184
# la valeur moyenne de l'attribut 34 est: 2.825
# l'écart-type de l'attribut 34 est: 2.4472773987978287
# la valeur moyenne de l'attribut 35 est: 2.4250000000000003
# l'écart-type de l'attribut 35 est: 2.032035104683644
# la valeur moyenne de l'attribut 36 est: 2.4
# l'écart-type de l'attribut 36 est: 2.1354156504062622
# la valeur moyenne de l'attribut 37 est: 2.625
# l'écart-type de l'attribut 37 est: 2.357081528783706
# la valeur moyenne de l'attribut 38 est: 2.5
# l'écart-type de l'attribut 38 est: 2.155612828563299
# la valeur moyenne de l'attribut 39 est: 2.225
# l'écart-type de l'attribut 39 est: 1.8518009252256753
# la valeur moyenne de l'attribut 40 est: 2.55
# l'écart-type de l'attribut 40 est: 2.1486429825977758
# la valeur moyenne de l'attribut 41 est: 2.525
# l'écart-type de l'attribut 41 est: 2.1234798484249073
# la valeur moyenne de l'attribut 42 est: 2.1
# l'écart-type de l'attribut 42 est: 1.7962924780409972
# la valeur moyenne de l'attribut 43 est: 2.2750000000000004
# l'écart-type de l'attribut 43 est: 1.8821530224718712
# la valeur moyenne de l'attribut 44 est: 2.675
# l'écart-type de l'attribut 44 est: 1.961929322546219
# la valeur moyenne de l'attribut 45 est: 2.8
# l'écart-type de l'attribut 45 est: 2.0704266871026045
# la valeur moyenne de l'attribut 46 est: 2.375
# l'écart-type de l'attribut 46 est: 1.960229578391266
# la valeur moyenne de l'attribut 47 est: 2.675
# l'écart-type de l'attribut 47 est: 2.1929812280698315
# la valeur moyenne de l'attribut 48 est: 2.35
# l'écart-type de l'attribut 48 est: 1.9416487838947598
# la valeur moyenne de l'attribut 49 est: 2.675
# l'écart-type de l'attribut 49 est: 2.2691775308835282
# la valeur moyenne de l'attribut 50 est: 2.475
# l'écart-type de l'attribut 50 est: 2.1124630174277605
# la valeur moyenne de l'attribut 51 est: 4.075
# l'écart-type de l'attribut 51 est: 2.3711811402758753
# la valeur moyenne de l'attribut 52 est: 3.9000000000000004
# l'écart-type de l'attribut 52 est: 2.070426687102605
# la valeur moyenne de l'attribut 53 est: 4.1000000000000005
# l'écart-type de l'attribut 53 est: 2.3266571155486866
# la valeur moyenne de l'attribut 54 est: 3.275
# l'écart-type de l'attribut 54 est: 1.8553975315279472
# la valeur moyenne de l'attribut 55 est: 3.8499999999999996
# l'écart-type de l'attribut 55 est: 2.1763884457207237
# la valeur moyenne de l'attribut 56 est: 3.575
# l'écart-type de l'attribut 56 est: 1.927649691550136
# la valeur moyenne de l'attribut 57 est: 3.975
# l'écart-type de l'attribut 57 est: 2.002290355234891
# la valeur moyenne de l'attribut 58 est: 2.9
# l'écart-type de l'attribut 58 est: 1.6350331291240963
# la valeur moyenne de l'attribut 59 est: 3.8499999999999996
# l'écart-type de l'attribut 59 est: 2.2752289262108696
# la valeur moyenne de l'attribut 60 est: 3.3
# l'écart-type de l'attribut 60 est: 1.6268579122549907
# la valeur moyenne de l'attribut 61 est: 2.875
# l'écart-type de l'attribut 61 est: 1.75
# la valeur moyenne de l'attribut 62 est: 3.6500000000000004
# l'écart-type de l'attribut 62 est: 1.862793601019716
# la valeur moyenne de l'attribut 63 est: 3.3
# l'écart-type de l'attribut 63 est: 2.181742422927143
# la valeur moyenne de l'attribut 64 est: 3.775
# l'écart-type de l'attribut 64 est: 2.0548722588034516
# la valeur moyenne de l'attribut 65 est: 3.35
# l'écart-type de l'attribut 65 est: 1.7823205847059798
# la valeur moyenne de l'attribut 66 est: 3.9000000000000004
# l'écart-type de l'attribut 66 est: 2.2345767682792492
# la valeur moyenne de l'attribut 67 est: 3.65
# l'écart-type de l'attribut 67 est: 1.786057109949175
# la valeur moyenne de l'attribut 68 est: 3.4
# l'écart-type de l'attribut 68 est: 2.0412414523193148
# la valeur moyenne de l'attribut 69 est: 3.6
# l'écart-type de l'attribut 69 est: 2.155612828563299
# la valeur moyenne de l'attribut 70 est: 3.275
# l'écart-type de l'attribut 70 est: 1.92591969372211
# la valeur moyenne de l'attribut 71 est: 3.9250000000000003
# l'écart-type de l'attribut 71 est: 1.7988422202442695
# la valeur moyenne de l'attribut 72 est: 3.55
# l'écart-type de l'attribut 72 est: 2.0273134932713295
# la valeur moyenne de l'attribut 73 est: 3.8
# l'écart-type de l'attribut 73 est: 2.193931022920578
# la valeur moyenne de l'attribut 74 est: 3.6999999999999997
# l'écart-type de l'attribut 74 est: 2.146314670934033
# la valeur moyenne de l'attribut 75 est: 3.725
# l'écart-type de l'attribut 75 est: 2.1639085008382404
# la valeur moyenne de l'attribut 76 est: 3.85
# l'écart-type de l'attribut 76 est: 2.2052966542697456
# la valeur moyenne de l'attribut 77 est: 3.9499999999999997
# l'écart-type de l'attribut 77 est: 2.3572582944316194
# la valeur moyenne de l'attribut 78 est: 4.1
# l'écart-type de l'attribut 78 est: 2.2015146301277824
# la valeur moyenne de l'attribut 79 est: 3.725
# l'écart-type de l'attribut 79 est: 1.95
# la valeur moyenne de l'attribut 80 est: 3.2
# l'écart-type de l'attribut 80 est: 1.9612920911140868
# la valeur moyenne de l'attribut 81 est: 3.2
# l'écart-type de l'attribut 81 est: 1.888562063228706
# la valeur moyenne de l'attribut 82 est: 3.15
# l'écart-type de l'attribut 82 est: 1.9157244060668017
# la valeur moyenne de l'attribut 83 est: 3.4
# l'écart-type de l'attribut 83 est: 1.944222209522358
# la valeur moyenne de l'attribut 84 est: 3.85
# l'écart-type de l'attribut 84 est: 2.046948949045872
# la valeur moyenne de l'attribut 85 est: 3.6
# l'écart-type de l'attribut 85 est: 1.7146428199482249
# la valeur moyenne de l'attribut 86 est: 3.875
# l'écart-type de l'attribut 86 est: 1.8536001007049316
# la valeur moyenne de l'attribut 87 est: 4.0
# l'écart-type de l'attribut 87 est: 2.2241103090149705
# la valeur moyenne de l'attribut 88 est: 3.575
# l'écart-type de l'attribut 88 est: 2.2291627725822685
# la valeur moyenne de l'attribut 89 est: 3.5
# l'écart-type de l'attribut 89 est: 1.8129166187849528
# la valeur moyenne de l'attribut 90 est: 3.325
# l'écart-type de l'attribut 90 est: 1.8227726133558184
# la valeur moyenne de l'attribut 91 est: 3.4250000000000003
# l'écart-type de l'attribut 91 est: 1.905037182489273
# la valeur moyenne de l'attribut 92 est: 3.775
# l'écart-type de l'attribut 92 est: 2.0271079563424013
# la valeur moyenne de l'attribut 93 est: 3.4
# l'écart-type de l'attribut 93 est: 1.96638416050035
# la valeur moyenne de l'attribut 94 est: 2.9
# l'écart-type de l'attribut 94 est: 1.687206764645835
# la valeur moyenne de l'attribut 95 est: 3.45
# l'écart-type de l'attribut 95 est: 1.859211302317912
# la valeur moyenne de l'attribut 96 est: 3.525
# l'écart-type de l'attribut 96 est: 1.9032866310674281
# la valeur moyenne de l'attribut 97 est: 3.525
# l'écart-type de l'attribut 97 est: 1.8732769861039416
# la valeur moyenne de l'attribut 98 est: 3.675
# l'écart-type de l'attribut 98 est: 2.0822663934601007
# la valeur moyenne de l'attribut 99 est: 2.925
# l'écart-type de l'attribut 99 est: 1.6580611166861932
# la valeur moyenne de l'attribut 100 est: 3.475
# l'écart-type de l'attribut 100 est: 1.8732769861039413
# la valeur moyenne de l'attribut 101 est: 4.525
# l'écart-type de l'attribut 101 est: 1.9085334683992314
# la valeur moyenne de l'attribut 102 est: 3.875
# l'écart-type de l'attribut 102 est: 1.8697147732564272
# la valeur moyenne de l'attribut 103 est: 4.525
# l'écart-type de l'attribut 103 est: 2.3613202521753234
# la valeur moyenne de l'attribut 104 est: 4.1499999999999995
# l'écart-type de l'attribut 104 est: 2.1455380055672126
# la valeur moyenne de l'attribut 105 est: 4.375
# l'écart-type de l'attribut 105 est: 2.0950338103874757
# la valeur moyenne de l'attribut 106 est: 4.825
# l'écart-type de l'attribut 106 est: 2.683747380063928
# la valeur moyenne de l'attribut 107 est: 3.4
# l'écart-type de l'attribut 107 est: 1.544884030167529
# la valeur moyenne de l'attribut 108 est: 4.575
# l'écart-type de l'attribut 108 est: 2.6399179280172076
# la valeur moyenne de l'attribut 109 est: 4.2
# l'écart-type de l'attribut 109 est: 2.4124676163629637
# la valeur moyenne de l'attribut 110 est: 4.85
# l'écart-type de l'attribut 110 est: 2.1733231083604054
# la valeur moyenne de l'attribut 111 est: 4.2
# l'écart-type de l'attribut 111 est: 1.9949937343260002
# la valeur moyenne de l'attribut 112 est: 4.075
# l'écart-type de l'attribut 112 est: 2.1234798484249073
# la valeur moyenne de l'attribut 113 est: 4.35
# l'écart-type de l'attribut 113 est: 2.1763884457207237
# la valeur moyenne de l'attribut 114 est: 3.8
# l'écart-type de l'attribut 114 est: 1.8239152027072603
# la valeur moyenne de l'attribut 115 est: 4.0249999999999995
# l'écart-type de l'attribut 115 est: 1.678044496827582
# la valeur moyenne de l'attribut 116 est: 4.3
# l'écart-type de l'attribut 116 est: 1.881488772222678
# la valeur moyenne de l'attribut 117 est: 4.2
# l'écart-type de l'attribut 117 est: 2.17408984788271
# la valeur moyenne de l'attribut 118 est: 5.1
# l'écart-type de l'attribut 118 est: 2.5442746183015177
# la valeur moyenne de l'attribut 119 est: 4.875
# l'écart-type de l'attribut 119 est: 2.8217902119044926
# la valeur moyenne de l'attribut 120 est: 3.675
# l'écart-type de l'attribut 120 est: 2.165448375433288
# la valeur moyenne de l'attribut 121 est: 4.525
# l'écart-type de l'attribut 121 est: 2.1391197566600457
# la valeur moyenne de l'attribut 122 est: 3.825
# l'écart-type de l'attribut 122 est: 1.7017148213885114
# la valeur moyenne de l'attribut 123 est: 4.8
# l'écart-type de l'attribut 123 est: 2.8201654797783293
# la valeur moyenne de l'attribut 124 est: 3.9250000000000003
# l'écart-type de l'attribut 124 est: 2.05
# la valeur moyenne de l'attribut 125 est: 4.45
# l'écart-type de l'attribut 125 est: 2.118962010041709
# la valeur moyenne de l'attribut 126 est: 4.55
# l'écart-type de l'attribut 126 est: 2.483948469674844
# la valeur moyenne de l'attribut 127 est: 3.9
# l'écart-type de l'attribut 127 est: 1.9765289440498124
# la valeur moyenne de l'attribut 128 est: 3.95
# l'écart-type de l'attribut 128 est: 1.9192012227313042
# la valeur moyenne de l'attribut 129 est: 4.225
# l'écart-type de l'attribut 129 est: 2.095033810387476
# la valeur moyenne de l'attribut 130 est: 4.4
# l'écart-type de l'attribut 130 est: 2.556038601690775
# la valeur moyenne de l'attribut 131 est: 4.55
# l'écart-type de l'attribut 131 est: 2.6210684844162313
# la valeur moyenne de l'attribut 132 est: 5.025
# l'écart-type de l'attribut 132 est: 2.633597033210156
# la valeur moyenne de l'attribut 133 est: 4.25
# l'écart-type de l'attribut 133 est: 2.0615528128088303
# la valeur moyenne de l'attribut 134 est: 3.925
# l'écart-type de l'attribut 134 est: 2.173131381210073
# la valeur moyenne de l'attribut 135 est: 3.925
# l'écart-type de l'attribut 135 est: 2.2852789764052877
# la valeur moyenne de l'attribut 136 est: 4.775
# l'écart-type de l'attribut 136 est: 2.5552234083669996
# la valeur moyenne de l'attribut 137 est: 4.425
# l'écart-type de l'attribut 137 est: 1.8300728582946273
# la valeur moyenne de l'attribut 138 est: 4.2
# l'écart-type de l'attribut 138 est: 2.121320343559643
# la valeur moyenne de l'attribut 139 est: 3.9
# l'écart-type de l'attribut 139 est: 1.865475810617763
# la valeur moyenne de l'attribut 140 est: 4.375
# l'écart-type de l'attribut 140 est: 2.177728174038257
# la valeur moyenne de l'attribut 141 est: 4.45
# l'écart-type de l'attribut 141 est: 2.0338797080129067
# la valeur moyenne de l'attribut 142 est: 4.35
# l'écart-type de l'attribut 142 est: 2.06801031589948
# la valeur moyenne de l'attribut 143 est: 3.875
# l'écart-type de l'attribut 143 est: 1.8697147732564272
# la valeur moyenne de l'attribut 144 est: 4.55
# l'écart-type de l'attribut 144 est: 2.142428528562855
# la valeur moyenne de l'attribut 145 est: 4.55
# l'écart-type de l'attribut 145 est: 1.9756855350316593
# la valeur moyenne de l'attribut 146 est: 4.3
# l'écart-type de l'attribut 146 est: 2.0215505600075074
# la valeur moyenne de l'attribut 147 est: 3.925
# l'écart-type de l'attribut 147 est: 2.0758532382292025
# la valeur moyenne de l'attribut 148 est: 4.175
# l'écart-type de l'attribut 148 est: 2.0467453839368166
# la valeur moyenne de l'attribut 149 est: 4.325
# l'écart-type de l'attribut 149 est: 1.7914147109663545
# la valeur moyenne de l'attribut 150 est: 3.95
# l'écart-type de l'attribut 150 est: 1.8841443681416772

# %%
n=1000
tab = ("lbfgs", "sgd", "adam")
for i in tab:
    print('--------------------',i,'--------------------')
    start_time = time.time()
    clf1 = MLPClassifier(solver=i,hidden_layer_sizes=(200),max_iter=n,random_state=0)
    clf1.fit(X_train,y_train)
    end_time = time.time()
    print(clf1.score(X_test,y_test))
    print('temps ecoulé pour une couche cachée = '+str(end_time - start_time))
    print('n_iter',clf1.n_iter_)
    start_time = time.time()
    clf2 = MLPClassifier(solver =i,hidden_layer_sizes=(100,200),max_iter=n,random_state=0)
    clf2.fit(X_train,y_train)
    end_time = time.time()
    print(clf2.score(X_test,y_test))
    print('temps ecoulé pour 2 couche cachée = '+str(end_time - start_time))
    print('n_iter',clf2.n_iter_)
    start_time = time.time()
    clf3 = MLPClassifier(solver =i,hidden_layer_sizes=(100,200,300),max_iter=n,random_state=0)
    clf3.fit(X_train,y_train)
    end_time = time.time()
    print(clf3.score(X_test,y_test))
    print('temps ecoulé 3 couche cachée = '+str(end_time - start_time))
    print('n_iter',clf3.n_iter_)
    start_time = time.time()
    clf4 = MLPClassifier(solver =i,hidden_layer_sizes=(100,150,250,300),max_iter=n,random_state=0)
    clf4.fit(X_train,y_train)
    end_time = time.time()
    print(clf4.score(X_test,y_test))
    print('temps ecoulé 4 couche cachée = '+str(end_time - start_time))
    print('n_iter',clf4.n_iter_)
    start_time = time.time()
    clf5= MLPClassifier(solver =i,hidden_layer_sizes=(50,100,150,200,250,300),max_iter=n,random_state=0)
    clf5.fit(X_train,y_train)
    end_time = time.time()
    print(clf5.score(X_test,y_test))
    print('temps ecoulé 5 couche cachée = '+str(end_time - start_time))
    print('n_iter',clf5.n_iter_)
    print('_________________________________________________________________')
# Out:
# -------------------- lbfgs --------------------
# 0.9619047619047619
# temps ecoulé pour une couche cachée = 0.03703498840332031
# n_iter 20
# 0.9619047619047619
# temps ecoulé pour 2 couche cachée = 0.1288442611694336
# n_iter 21
# 0.9619047619047619
# temps ecoulé 3 couche cachée = 0.5603196620941162
# n_iter 25
# 0.9619047619047619
# temps ecoulé 4 couche cachée = 0.9386575222015381
# n_iter 26
# 0.9523809523809523
# temps ecoulé 5 couche cachée = 4.265818357467651
# n_iter 91
# _________________________________________________________________
# -------------------- sgd --------------------
# 0.8476190476190476
# temps ecoulé pour une couche cachée = 0.9529769420623779
# n_iter 899
# C:\Users\utilisateur\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# 0.8952380952380953
# temps ecoulé pour 2 couche cachée = 1.7930026054382324
# n_iter 1000
# 0.9333333333333333
# temps ecoulé 3 couche cachée = 3.788252592086792
# n_iter 979
# 0.9523809523809523
# temps ecoulé 4 couche cachée = 4.6702985763549805
# n_iter 890
# 0.9523809523809523
# temps ecoulé 5 couche cachée = 5.430448055267334
# n_iter 758
# _________________________________________________________________
# -------------------- adam --------------------
# 0.9619047619047619
# temps ecoulé pour une couche cachée = 0.5190973281860352
# n_iter 455
# 0.9428571428571428
# temps ecoulé pour 2 couche cachée = 0.44471025466918945
# n_iter 229
# 0.9428571428571428
# temps ecoulé 3 couche cachée = 0.45997023582458496
# n_iter 108
# 0.9428571428571428
# temps ecoulé 4 couche cachée = 0.4910881519317627
# n_iter 72
# 0.9428571428571428
# temps ecoulé 5 couche cachée = 0.4994850158691406
# n_iter 53
# _________________________________________________________________

# %%
param_grid = {
    'alpha': [0.0001, 0.001, 0.1, 1]
    }
 
mlp_clf = GridSearchCV(MLPClassifier(hidden_layer_sizes = (2),activation = 'logistic', solver = 'lbfgs', learning_rate = 'adaptive', max_iter = 100), param_grid, cv=2, n_jobs=4, verbose=1)
mlp_clf.fit(X_train, y_train)
print("Le score est: ", mlp_clf.score(X_test, y_test))
print("La meilleure valeur pour alpha = {}".format(mlp_clf.best_estimator_.alpha))
# Out:
# Fitting 2 folds for each of 4 candidates, totalling 8 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Le score est:  0.9619047619047619
# La meilleure valeur pour alpha = 0.001
# [Parallel(n_jobs=4)]: Done   8 out of   8 | elapsed:    2.6s finished

# %%
import matplotlib.pyplot as plt
import time
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import fetch_openml
mnist = fetch_openml("mnist_784")

X, y = mnist.data / 255., mnist.target
X_train, X_test = X[:60000], X[60000:]
y_train, y_test = y[:60000], y[60000:]


start_time = time.time()

mlp = MLPClassifier(hidden_layer_sizes=(50,), max_iter=10, alpha=1e-4,
                    solver='sgd', verbose=10, tol=1e-4, random_state=1,
                    learning_rate_init=.1)

mlp.fit(X_train, y_train)
end_time = time.time()
print("le score d'entrainement est : %f" % mlp.score(X_train, y_train))
print("le score de test est : %f" % mlp.score(X_test, y_test))
print('temps ecoulé = '+str(end_time - start_time))
# Out:
# Iteration 1, loss = 0.32009978
# Iteration 2, loss = 0.15347534
# Iteration 3, loss = 0.11544755
# Iteration 4, loss = 0.09279764
# Iteration 5, loss = 0.07889367
# Iteration 6, loss = 0.07170497
# Iteration 7, loss = 0.06282111
# Iteration 8, loss = 0.05530788
# Iteration 9, loss = 0.04960484
# Iteration 10, loss = 0.04645355
# C:\Users\utilisateur\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:582: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (10) reached and the optimization hasn't converged yet.
#   warnings.warn(
# le score d'entrainement est : 0.986800
# le score de test est : 0.970000
# temps ecoulé = 65.73171329498291

# %%
from sklearn.model_selection import GridSearchCV

#Appliquons un GridSearchCV pour trouver la meilleure configuration possible
param_grid = {
    'hidden_layer_sizes': [2, 30, 40, 50],
    'activation':['logistic','relu'],
    'solver':['lbfgs', 'sgd', 'adam'],
    'learning_rate':['adaptive'],
    'alpha': [0.0001, 0.001,0.01]
    }
 
mlp_clf = GridSearchCV(MLPClassifier(), param_grid, cv=3, n_jobs=4, verbose=1)
mlp_clf.fit(X_train_flat, y_train)
y_predict = mlp_clf.predict(X_test_flat)
print("Meilleur score : " + str(svm_clf.best_estimator_.score(X_test_flat, y_test)))
print("La meilleure configuration est: " + str(svm_clf.best_params_))
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.

# %%
import numpy as np
import time
import matplotlib.pyplot as plt
from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Perceptron 
from sklearn.preprocessing import StandardScaler

iris = datasets.load_iris()

X= iris.data
y= iris.target
print(X)
iris.head()
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.2]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.6 1.4 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
#  [4.6 3.2 1.4 0.2]
#  [5.3 3.7 1.5 0.2]
#  [5.  3.3 1.4 0.2]
#  [7.  3.2 4.7 1.4]
#  [6.4 3.2 4.5 1.5]
#  [6.9 3.1 4.9 1.5]
#  [5.5 2.3 4.  1.3]
#  [6.5 2.8 4.6 1.5]
#  [5.7 2.8 4.5 1.3]
#  [6.3 3.3 4.7 1.6]
#  [4.9 2.4 3.3 1. ]
#  [6.6 2.9 4.6 1.3]
#  [5.2 2.7 3.9 1.4]
#  [5.  2.  3.5 1. ]
#  [5.9 3.  4.2 1.5]
#  [6.  2.2 4.  1. ]
#  [6.1 2.9 4.7 1.4]
#  [5.6 2.9 3.6 1.3]
#  [6.7 3.1 4.4 1.4]
#  [5.6 3.  4.5 1.5]
#  [5.8 2.7 4.1 1. ]
#  [6.2 2.2 4.5 1.5]
#  [5.6 2.5 3.9 1.1]
#  [5.9 3.2 4.8 1.8]
#  [6.1 2.8 4.  1.3]
#  [6.3 2.5 4.9 1.5]
#  [6.1 2.8 4.7 1.2]
#  [6.4 2.9 4.3 1.3]
#  [6.6 3.  4.4 1.4]
#  [6.8 2.8 4.8 1.4]
#  [6.7 3.  5.  1.7]
#  [6.  2.9 4.5 1.5]
#  [5.7 2.6 3.5 1. ]
#  [5.5 2.4 3.8 1.1]
#  [5.5 2.4 3.7 1. ]
#  [5.8 2.7 3.9 1.2]
#  [6.  2.7 5.1 1.6]
#  [5.4 3.  4.5 1.5]
#  [6.  3.4 4.5 1.6]
#  [6.7 3.1 4.7 1.5]
#  [6.3 2.3 4.4 1.3]
#  [5.6 3.  4.1 1.3]
#  [5.5 2.5 4.  1.3]
#  [5.5 2.6 4.4 1.2]
#  [6.1 3.  4.6 1.4]
#  [5.8 2.6 4.  1.2]
#  [5.  2.3 3.3 1. ]
#  [5.6 2.7 4.2 1.3]
#  [5.7 3.  4.2 1.2]
#  [5.7 2.9 4.2 1.3]
#  [6.2 2.9 4.3 1.3]
#  [5.1 2.5 3.  1.1]
#  [5.7 2.8 4.1 1.3]
#  [6.3 3.3 6.  2.5]
#  [5.8 2.7 5.1 1.9]
#  [7.1 3.  5.9 2.1]
#  [6.3 2.9 5.6 1.8]
#  [6.5 3.  5.8 2.2]
#  [7.6 3.  6.6 2.1]
#  [4.9 2.5 4.5 1.7]
#  [7.3 2.9 6.3 1.8]
#  [6.7 2.5 5.8 1.8]
#  [7.2 3.6 6.1 2.5]
#  [6.5 3.2 5.1 2. ]
#  [6.4 2.7 5.3 1.9]
#  [6.8 3.  5.5 2.1]
#  [5.7 2.5 5.  2. ]
#  [5.8 2.8 5.1 2.4]
#  [6.4 3.2 5.3 2.3]
#  [6.5 3.  5.5 1.8]
#  [7.7 3.8 6.7 2.2]
#  [7.7 2.6 6.9 2.3]
#  [6.  2.2 5.  1.5]
#  [6.9 3.2 5.7 2.3]
#  [5.6 2.8 4.9 2. ]
#  [7.7 2.8 6.7 2. ]
#  [6.3 2.7 4.9 1.8]
#  [6.7 3.3 5.7 2.1]
#  [7.2 3.2 6.  1.8]
#  [6.2 2.8 4.8 1.8]
#  [6.1 3.  4.9 1.8]
#  [6.4 2.8 5.6 2.1]
#  [7.2 3.  5.8 1.6]
#  [7.4 2.8 6.1 1.9]
#  [7.9 3.8 6.4 2. ]
#  [6.4 2.8 5.6 2.2]
#  [6.3 2.8 5.1 1.5]
#  [6.1 2.6 5.6 1.4]
#  [7.7 3.  6.1 2.3]
#  [6.3 3.4 5.6 2.4]
#  [6.4 3.1 5.5 1.8]
#  [6.  3.  4.8 1.8]
#  [6.9 3.1 5.4 2.1]
#  [6.7 3.1 5.6 2.4]
#  [6.9 3.1 5.1 2.3]
#  [5.8 2.7 5.1 1.9]
#  [6.8 3.2 5.9 2.3]
#  [6.7 3.3 5.7 2.5]
#  [6.7 3.  5.2 2.3]
#  [6.3 2.5 5.  1.9]
#  [6.5 3.  5.2 2. ]
#  [6.2 3.4 5.4 2.3]
#  [5.9 3.  5.1 1.8]]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sklearn\utils\__init__.py in __getattr__(self, key)
#      95         try:
# ---> 96             return self[key]
#      97         except KeyError:
#
# KeyError: 'head'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-5684d9806d45> in <module>
#      13 y= iris.target
#      14 print(X)
# ---> 15 iris.head()
#
# ~\anaconda3\lib\site-packages\sklearn\utils\__init__.py in __getattr__(self, key)
#      96             return self[key]
#      97         except KeyError:
# ---> 98             raise AttributeError(key)
#      99
#     100     def __setstate__(self, state):
#
# AttributeError: head
